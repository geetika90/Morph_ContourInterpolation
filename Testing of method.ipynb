# %%
import sys
sys.path.insert(1,'/ContourInterpolationMethod')
from ContourInterpolationMethod.ToyDataTest  import InterpToyData
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Method with Toy Data

# %%
InterpToyData('Toy image')
